# %%
# Laden der Daten aus einer CSV-Datei 
import pandas as pd
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent

def load_data(filename: str) -> pd.DataFrame:
    data_path = PROJECT_ROOT / "data" / "raw" / filename

    if not data_path.exists():
        raise FileNotFoundError(f"Datei nicht gefunden: {data_path.resolve()}")
    
    return pd.read_csv(data_path)

# %%
# Rohdaten DataFrame
df_kba = load_data("Top50Modellreihen_aktuell_-7143260394302912301.csv")
df_kba.head()
df_kba.columns
# Out:
# Index(['Berichtsjahr', 'Berichtsmonat', 'Modellreihe', 'Anzahl', 'ZS Anzahl',
#        'ObjectId'],
#       dtype='object')
